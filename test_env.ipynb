# %%
import sys
import pandas as pd
import numpy as np

print("Python Executable Path:", sys.executable)
print("Pandas version:", pd.__version__)
print("Numpy version:", np.__version__)
# Out:
# Python Executable Path: /opt/homebrew/Caskroom/miniforge/base/envs/quant-prep/bin/python
# Pandas version: 2.3.3
# Numpy version: 2.2.6

# %%
from config.core import set_seed, get_logger

# 1. Lock the seed
set_seed(42)

# 2. Test the logger
logger = get_logger("Stage_0_Test")
logger.info("Environment locked, loaded, and reproducible.")

# 3. Test randomness (this will now print the exact same number every time)
print("Random Number:", np.random.rand())
# Out:
# 2026-02-16 13:26:55,951 - Stage_0_Test - INFO - Environment locked, loaded, and reproducible.
# Random Number: 0.3745401188473625
